# %%
using OnlineStats
using Plots, PlotThemes

y = cumsum(randn(10^6)) + 100randn(10^6)

o = Partition(KHist(10))

fit!(o, y)

plot(o)
# Out:
# MethodError: Cannot `convert` an object of type Array{Any,1} to an object of type RecipeData
# Closest candidates are:
#   convert(::Type{T}, !Matched::T) where T at essentials.jl:171
#   RecipeData(::Any, !Matched::Any) at /home/zhangyong/.julia/packages/RecipesBase/zBoFG/src/RecipesBase.jl:53
#
# Stacktrace:
#  [1] setindex!(::Array{RecipeData,1}, ::Array{Any,1}, ::Int64) at ./array.jl:847
#  [2] _prepend! at ./array.jl:1038 [inlined]
#  [3] prepend!(::Array{RecipeData,1}, ::Tuple{Array{Any,1},Array{Float64,1}}) at ./array.jl:1029
#  [4] _process_userrecipes(::Plots.Plot{Plots.GRBackend}, ::Dict{Symbol,Any}, ::Tuple{Partition{Float64,KHist{Float64}}}) at /home/zhangyong/.julia/packages/Plots/qZHsp/src/pipeline.jl:84
#  [5] _plot!(::Plots.Plot{Plots.GRBackend}, ::Dict{Symbol,Any}, ::Tuple{Partition{Float64,KHist{Float64}}}) at /home/zhangyong/.julia/packages/Plots/qZHsp/src/plot.jl:178
#  [6] plot(::Partition{Float64,KHist{Float64}}; kw::Base.Iterators.Pairs{Union{},Union{},Tuple{},NamedTuple{(),Tuple{}}}) at /home/zhangyong/.julia/packages/Plots/qZHsp/src/plot.jl:57
#  [7] plot(::Partition{Float64,KHist{Float64}}) at /home/zhangyong/.julia/packages/Plots/qZHsp/src/plot.jl:51
#  [8] top-level scope at In[9]:10
#  [9] include_string(::Function, ::Module, ::String, ::String) at ./loading.jl:1091
#  [10] execute_code(::String, ::String) at /home/zhangyong/.julia/packages/IJulia/rWZ9e/src/execute_request.jl:27
#  [11] execute_request(::ZMQ.Socket, ::IJulia.Msg) at /home/zhangyong/.julia/packages/IJulia/rWZ9e/src/execute_request.jl:86
#  [12] #invokelatest#1 at ./essentials.jl:710 [inlined]
#  [13] invokelatest at ./essentials.jl:709 [inlined]
#  [14] eventloop(::ZMQ.Socket) at /home/zhangyong/.julia/packages/IJulia/rWZ9e/src/eventloop.jl:8
#  [15] (::IJulia.var"#15#18")() at ./task.jl:356

# %%
# using Dates, CSV, JuliaDB, ProgressMeter
# Interact, HTTP, SingularSpectrumAnalysis, 
using OnlineStats, ProgressMeter
using Plots, PlotThemes
theme(:bright)

o = Partition(Series(Mean()))  # , Extrema()

y = randn()

@showprogress for _ in 1:10^3
    fit!(o,  global y += randn())
end

# println(o)
plot(o)
# Out:
# Progress: 100%|█████████████████████████████████████████| Time: 0:00:01
# MethodError: Cannot `convert` an object of type Array{Int64,1} to an object of type RecipeData
# Closest candidates are:
#   convert(::Type{T}, !Matched::T) where T at essentials.jl:171
#   RecipeData(::Any, !Matched::Any) at /home/zhangyong/.julia/packages/RecipesBase/zBoFG/src/RecipesBase.jl:53
#
# Stacktrace:
#  [1] setindex!(::Array{RecipeData,1}, ::Array{Int64,1}, ::Int64) at ./array.jl:847
#  [2] _prepend! at ./array.jl:1038 [inlined]
#  [3] prepend!(::Array{RecipeData,1}, ::Tuple{Array{Int64,1},Array{Float64,1}}) at ./array.jl:1029
#  [4] _process_userrecipes(::Plots.Plot{Plots.GRBackend}, ::Dict{Symbol,Any}, ::Tuple{Partition{Number,Series{Number,Tuple{Mean{Float64,EqualWeight}}}}}) at /home/zhangyong/.julia/packages/Plots/qZHsp/src/pipeline.jl:84
#  [5] _plot!(::Plots.Plot{Plots.GRBackend}, ::Dict{Symbol,Any}, ::Tuple{Partition{Number,Series{Number,Tuple{Mean{Float64,EqualWeight}}}}}) at /home/zhangyong/.julia/packages/Plots/qZHsp/src/plot.jl:178
#  [6] plot(::Partition{Number,Series{Number,Tuple{Mean{Float64,EqualWeight}}}}; kw::Base.Iterators.Pairs{Union{},Union{},Tuple{},NamedTuple{(),Tuple{}}}) at /home/zhangyong/.julia/packages/Plots/qZHsp/src/plot.jl:57
#  [7] plot(::Partition{Number,Series{Number,Tuple{Mean{Float64,EqualWeight}}}}) at /home/zhangyong/.julia/packages/Plots/qZHsp/src/plot.jl:51
#  [8] top-level scope at In[1]:16
#  [9] include_string(::Function, ::Module, ::String, ::String) at ./loading.jl:1091
#  [10] execute_code(::String, ::String) at /home/zhangyong/.julia/packages/IJulia/rWZ9e/src/execute_request.jl:27
#  [11] execute_request(::ZMQ.Socket, ::IJulia.Msg) at /home/zhangyong/.julia/packages/IJulia/rWZ9e/src/execute_request.jl:86
#  [12] #invokelatest#1 at ./essentials.jl:710 [inlined]
#  [13] invokelatest at ./essentials.jl:709 [inlined]
#  [14] eventloop(::ZMQ.Socket) at /home/zhangyong/.julia/packages/IJulia/rWZ9e/src/eventloop.jl:8
#  [15] (::IJulia.var"#15#18")() at ./task.jl:356

# %%
using OnlineStats, CSV, Plots

url = "https://gist.githubusercontent.com/joshday/df7bdaa1d58b398592e7656395de6335/raw/5a1c83f498f8ca7e25ff2372340e44b3389be9b1/iris.csv"
rows = CSV.Rows(open("data/iris.txt"); reusebuffer=true)
# rows = CSV.Rows(download(url); reusebuffer = true)

itr = (row.variety => parse(Float64, row.sepal_length) for row in rows)

o = GroupBy(String, Hist(4:0.25:8))

fit!(o, itr)

plot(o, layout=(3,1))
