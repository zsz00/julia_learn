# %%
using Plots,OnlineStats
using ThreadsX

y = cumsum(randn(10^6)) + 100randn(10^6)
o = Partition(KHist(10))
fit!(o, y)
# ThreadsX.reduce(o, y)  # 此处不行
plot(o)
# Out:
# BoundsError: attempt to access 123-element Array{Pair{Tuple{Int64,Int64},KHist{Float64}},1} at index [124]
#
# Stacktrace:
#  [1] getindex at ./array.jl:809 [inlined]
#  [2] merge_next!(::Array{Pair{Tuple{Int64,Int64},KHist{Float64}},1}) at /home/zhangyong/.julia/packages/OnlineStats/qsfdK/src/viz/partition.jl:49
#  [3] _merge!(::Partition{Float64,KHist{Float64}}, ::Partition{Float64,KHist{Float64}}) at /home/zhangyong/.julia/packages/OnlineStats/qsfdK/src/viz/partition.jl:62
#  [4] merge! at /home/zhangyong/.julia/packages/OnlineStatsBase/OqLB6/src/OnlineStatsBase.jl:77 [inlined]
#  [5] combine at /home/zhangyong/.julia/packages/Transducers/AgX5g/src/interop/onlinestats.jl:87 [inlined]
#  [6] combine at /home/zhangyong/.julia/packages/Transducers/AgX5g/src/core.jl:748 [inlined]
#  [7] combine(::Transducers.BottomRF{Transducers.Completing{Transducers.OnlineStatReducingFunction{Partition{Float64,KHist{Float64}}}}}, ::Partition{Float64,KHist{Float64}}, ::Partition{Float64,KHist{Float64}}) at /home/zhangyong/.julia/packages/Transducers/AgX5g/src/core.jl:291
#  [8] _reduce(::Transducers.TaskContext, ::Bool, ::Task, ::Transducers.BottomRF{Transducers.Completing{Transducers.OnlineStatReducingFunction{Partition{Float64,KHist{Float64}}}}}, ::InitialValues.InitialValueOf{Partition{Float64,KHist{Float64}}}, ::Transducers.SizedReducible{SubArray{Float64,1,Array{Float64,1},Tuple{UnitRange{Int64}},true},Int64}) at /home/zhangyong/.julia/packages/Transducers/AgX5g/src/reduce.jl:254
#  [9] _reduce(::Transducers.TaskContext, ::Bool, ::Task, ::Transducers.BottomRF{Transducers.Completing{Transducers.OnlineStatReducingFunction{Partition{Float64,KHist{Float64}}}}}, ::InitialValues.InitialValueOf{Partition{Float64,KHist{Float64}}}, ::Transducers.SizedReducible{SubArray{Float64,1,Array{Float64,1},Tuple{UnitRange{Int64}},true},Int64}) at /home/zhangyong/.julia/packages/Transducers/AgX5g/src/reduce.jl:249 (repeats 2 times)
#  [10] _transduce_assoc_nocomplete at /home/zhangyong/.julia/packages/Transducers/AgX5g/src/reduce.jl:210 [inlined]
#  [11] #transduce_assoc#134 at /home/zhangyong/.julia/packages/Transducers/AgX5g/src/reduce.jl:179 [inlined]
#  [12] foldxt(::Transducers.OnlineStatReducingFunction{Partition{Float64,KHist{Float64}}}, ::Transducers.IdentityTransducer, ::Array{Float64,1}; init::InitialValues.InitialValueOf{Partition{Float64,KHist{Float64}}}, kwargs::Base.Iterators.Pairs{Symbol,Int64,Tuple{Symbol},NamedTuple{(:basesize,),Tuple{Int64}}}) at /home/zhangyong/.julia/packages/Transducers/AgX5g/src/reduce.jl:329
#  [13] #foldxt#269 at /home/zhangyong/.julia/packages/Transducers/AgX5g/src/interop/onlinestats.jl:121 [inlined]
#  [14] #reduce#10 at /home/zhangyong/.julia/packages/ThreadsX/XjdfU/src/reduce.jl:5 [inlined]
#  [15] reduce(::Partition{Float64,KHist{Float64}}, ::Array{Float64,1}) at /home/zhangyong/.julia/packages/ThreadsX/XjdfU/src/reduce.jl:4
#  [16] top-level scope at In[5]:7
#  [17] include_string(::Function, ::Module, ::String, ::String) at ./loading.jl:1091
#  [18] execute_code(::String, ::String) at /home/zhangyong/.julia/packages/IJulia/rWZ9e/src/execute_request.jl:27
#  [19] execute_request(::ZMQ.Socket, ::IJulia.Msg) at /home/zhangyong/.julia/packages/IJulia/rWZ9e/src/execute_request.jl:86
#  [20] #invokelatest#1 at ./essentials.jl:710 [inlined]
#  [21] invokelatest at ./essentials.jl:709 [inlined]
#  [22] eventloop(::ZMQ.Socket) at /home/zhangyong/.julia/packages/IJulia/rWZ9e/src/eventloop.jl:8
#  [23] (::IJulia.var"#15#18")() at ./task.jl:356

# %%
# s = fit!(Series(KHist(25), Hist(-5:.2:5), ExpandingHist(100)), randn(10^6))
s = ThreadsX.reduce(Series(KHist(25), Hist(-5:.2:5), ExpandingHist(100)), randn(10^6))
plot(s, link = :x, label = ["KHist" "Hist" "ExpandingHist"])
# Out:
# ┌ Warning: Merging ExpandingHist{Number,StepRangeLen{Float64,TwicePrecision{Float64},TwicePrecision{Float64}}} into ExpandingHist{Number,StepRangeLen{Float64,TwicePrecision{Float64},TwicePrecision{Float64}}} is not well-defined.  No merging occurred.
# └ @ OnlineStatsBase /home/zhangyong/.julia/packages/OnlineStatsBase/OqLB6/src/OnlineStatsBase.jl:80
# ┌ Warning: Merging ExpandingHist{Number,StepRangeLen{Float64,TwicePrecision{Float64},TwicePrecision{Float64}}} into ExpandingHist{Number,StepRangeLen{Float64,TwicePrecision{Float64},TwicePrecision{Float64}}} is not well-defined.  No merging occurred.
# └ @ OnlineStatsBase /home/zhangyong/.julia/packages/OnlineStatsBase/OqLB6/src/OnlineStatsBase.jl:80
# ┌ Warning: Merging ExpandingHist{Number,StepRangeLen{Float64,TwicePrecision{Float64},TwicePrecision{Float64}}} into ExpandingHist{Number,StepRangeLen{Float64,TwicePrecision{Float64},TwicePrecision{Float64}}} is not well-defined.  No merging occurred.
# └ @ OnlineStatsBase /home/zhangyong/.julia/packages/OnlineStatsBase/OqLB6/src/OnlineStatsBase.jl:80
# ┌ Warning: Merging ExpandingHist{Number,StepRangeLen{Float64,TwicePrecision{Float64},TwicePrecision{Float64}}} into ExpandingHist{Number,StepRangeLen{Float64,TwicePrecision{Float64},TwicePrecision{Float64}}} is not well-defined.  No merging occurred.
# └ @ OnlineStatsBase /home/zhangyong/.julia/packages/OnlineStatsBase/OqLB6/src/OnlineStatsBase.jl:80
# ┌ Warning: Merging ExpandingHist{Number,StepRangeLen{Float64,TwicePrecision{Float64},TwicePrecision{Float64}}} into ExpandingHist{Number,StepRangeLen{Float64,TwicePrecision{Float64},TwicePrecision{Float64}}} is not well-defined.  No merging occurred.
# └ @ OnlineStatsBase /home/zhangyong/.julia/packages/OnlineStatsBase/OqLB6/src/OnlineStatsBase.jl:80
# ┌ Warning: Merging ExpandingHist{Number,StepRangeLen{Float64,TwicePrecision{Float64},TwicePrecision{Float64}}} into ExpandingHist{Number,StepRangeLen{Float64,TwicePrecision{Float64},TwicePrecision{Float64}}} is not well-defined.  No merging occurred.
# └ @ OnlineStatsBase /home/zhangyong/.julia/packages/OnlineStatsBase/OqLB6/src/OnlineStatsBase.jl:80
# ┌ Warning: Merging ExpandingHist{Number,StepRangeLen{Float64,TwicePrecision{Float64},TwicePrecision{Float64}}} into ExpandingHist{Number,StepRangeLen{Float64,TwicePrecision{Float64},TwicePrecision{Float64}}} is not well-defined.  No merging occurred.
# └ @ OnlineStatsBase /home/zhangyong/.julia/packages/OnlineStatsBase/OqLB6/src/OnlineStatsBase.jl:80

# %%
using Dates, CSV, Plots, PlotThemes, ProgressMeter
# Interact, HTTP, SingularSpectrumAnalysis, JuliaDB,
using OnlineStats
theme(:bright)

o = Partition(Series(Mean(), Extrema()))

y = randn()

@showprogress for _ in 1:10^3
    fit!(o,  global y += randn())
#     plot(o)
end

# println(o)
plot(o)  # 不能画出动态的

# %%
using OnlineStats, CSV, Plots

url = "https://gist.githubusercontent.com/joshday/df7bdaa1d58b398592e7656395de6335/raw/5a1c83f498f8ca7e25ff2372340e44b3389be9b1/iris.csv"
rows = CSV.Rows(open("data/iris.txt"); reusebuffer=true)
# rows = CSV.Rows(download(url); reusebuffer = true)

itr = (row.variety => parse(Float64, row.sepal_length) for row in rows)

o = GroupBy(String, Hist(4:0.25:8))

# fit!(o, itr)
ThreadsX.reduce(o, itr)
plot(o, layout=(3,1))
# Out:
# MethodError: no method matching length(::CSV.Rows{false,Parsers.Options{false,false,true,false,Missing,UInt8,Nothing},Nothing,Array{UInt8,1},DataType,UInt64})
# Closest candidates are:
#   length(!Matched::DataStructures.SparseIntSet) at /home/zhangyong/.julia/packages/DataStructures/DLSxi/src/sparse_int_set.jl:61
#   length(!Matched::Base.MethodList) at reflection.jl:872
#   length(!Matched::LibGit2.GitBlob) at /buildworker/worker/package_linux64/build/usr/share/julia/stdlib/v1.5/LibGit2/src/blob.jl:3
#   ...
#
# Stacktrace:
#  [1] amount(::CSV.Rows{false,Parsers.Options{false,false,true,false,Missing,UInt8,Nothing},Nothing,Array{UInt8,1},DataType,UInt64}) at /home/zhangyong/.julia/packages/SplittablesBase/dZ3Qr/src/implementations.jl:65
#  [2] default_basesize(::CSV.Rows{false,Parsers.Options{false,false,true,false,Missing,UInt8,Nothing},Nothing,Array{UInt8,1},DataType,UInt64}) at /home/zhangyong/.julia/packages/ThreadsX/XjdfU/src/basesizes.jl:2
#  [3] reduce(::GroupBy{String,Float64,Hist{Float64,StepRangeLen{Float64,Base.TwicePrecision{Float64},Base.TwicePrecision{Float64}}}}, ::Base.Generator{CSV.Rows{false,Parsers.Options{false,false,true,false,Missing,UInt8,Nothing},Nothing,Array{UInt8,1},DataType,UInt64},var"#2#3"}; kw::Base.Iterators.Pairs{Union{},Union{},Tuple{},NamedTuple{(),Tuple{}}}) at /home/zhangyong/.julia/packages/ThreadsX/XjdfU/src/reduce.jl:5
#  [4] reduce(::GroupBy{String,Float64,Hist{Float64,StepRangeLen{Float64,Base.TwicePrecision{Float64},Base.TwicePrecision{Float64}}}}, ::Base.Generator{CSV.Rows{false,Parsers.Options{false,false,true,false,Missing,UInt8,Nothing},Nothing,Array{UInt8,1},DataType,UInt64},var"#2#3"}) at /home/zhangyong/.julia/packages/ThreadsX/XjdfU/src/reduce.jl:4
#  [5] top-level scope at In[6]:12
#  [6] include_string(::Function, ::Module, ::String, ::String) at ./loading.jl:1091
#  [7] execute_code(::String, ::String) at /home/zhangyong/.julia/packages/IJulia/rWZ9e/src/execute_request.jl:27
#  [8] execute_request(::ZMQ.Socket, ::IJulia.Msg) at /home/zhangyong/.julia/packages/IJulia/rWZ9e/src/execute_request.jl:86
#  [9] #invokelatest#1 at ./essentials.jl:710 [inlined]
#  [10] invokelatest at ./essentials.jl:709 [inlined]
#  [11] eventloop(::ZMQ.Socket) at /home/zhangyong/.julia/packages/IJulia/rWZ9e/src/eventloop.jl:8
#  [12] (::IJulia.var"#15#18")() at ./task.jl:356

# %%
using Plots
# define the Lorenz attractor
Base.@kwdef mutable struct Lorenz
    dt::Float64 = 0.02
    σ::Float64 = 10
    ρ::Float64 = 28
    β::Float64 = 8/3
    x::Float64 = 1
    y::Float64 = 1
    z::Float64 = 1
end

function step!(l::Lorenz)
    dx = l.σ * (l.y - l.x);         l.x += l.dt * dx
    dy = l.x * (l.ρ - l.z) - l.y;   l.y += l.dt * dy
    dz = l.x * l.y - l.β * l.z;     l.z += l.dt * dz
end

attractor = Lorenz()


# initialize a 3D plot with 1 empty series
plt = plot3d(
    1,
    xlim = (-30, 30),
    ylim = (-30, 30),
    zlim = (0, 60),
    title = "Lorenz Attractor",
    marker = 2,
)

# build an animated gif by pushing new points to the plot, saving every 10th frame
@gif for i=1:1500
    step!(attractor)
    push!(plt, attractor.x, attractor.y, attractor.z)
end every 10
# Out:
# ┌ Info: Saved animation to
# │   fn = /home/zhangyong/cluster/julia_learn/cluster/stream/tmp.gif
# └ @ Plots /home/zhangyong/.julia/packages/Plots/uCh2y/src/animation.jl:104
# Plots.AnimatedGif("/home/zhangyong/cluster/julia_learn/cluster/stream/tmp.gif")

# %%
ThreadsX.reduce(Mean(), 1:10)
# Out:
# Mean: n=10 | value=5.5
