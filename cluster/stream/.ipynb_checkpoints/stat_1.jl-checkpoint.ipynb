# %%
using DataFrames
using PyCall
using Pandas
# np = pyimport("numpy")
pd = Pandas   # pyimport("pandas")
# Out:
# Pandas

# %%
pkl_path = "/data/zhangyong/data/nj_1/output_2/merged_all_out_1_1_4_1.pkl"
obj_info = pd.read_pickle(pkl_path)  # 太慢了
# obj_info = pd.DataFrame(obj_info)
# print(obj_info.shape)

# %%
# aa = obj_info[obj_info['delegate']==True].groupby('person_id')

println(typeof(obj_info))
df = DataFrames.DataFrame(obj_info)
println(typeof(df))

combine(groupby(df, :person_id), :person_id=>count=>:aa)
# Out:
# Pandas.DataFrame
# UndefVarError: DataFrame not defined
#
# Stacktrace:
#  [1] top-level scope at In[12]:5
#  [2] include_string(::Function, ::Module, ::String, ::String) at ./loading.jl:1091
#  [3] execute_code(::String, ::String) at /home/zhangyong/.julia/packages/IJulia/a1SNk/src/execute_request.jl:27
#  [4] execute_request(::ZMQ.Socket, ::IJulia.Msg) at /home/zhangyong/.julia/packages/IJulia/a1SNk/src/execute_request.jl:86
#  [5] #invokelatest#1 at ./essentials.jl:710 [inlined]
#  [6] invokelatest at ./essentials.jl:709 [inlined]
#  [7] eventloop(::ZMQ.Socket) at /home/zhangyong/.julia/packages/IJulia/a1SNk/src/eventloop.jl:8
#  [8] (::IJulia.var"#15#18")() at ./task.jl:356
