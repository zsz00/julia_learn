# %%
using CSV, LinearAlgebra, Statistics, Compat, GLM, DataFrames
using Plots
using RDatasets
using MLJ

# %%
# data = DataFrame(y = rand(100), x = categorical(repeat([1, 2, 3, 4], 25)))
x = rand(100)
data = DataFrame(x =x, y = 2x .+ 0.1*rand(100))
println(data.x)
println(lm(@formula(y ~ x), data))

x_data = convert(Array, data[:x])
y_data = convert(Array,data[:y])
s = scatter(x_data, y_data )

theta_1 = 0.0547491
theta_2 = 1.99782
plot!(s, x_data, x_data * theta_2 .+ theta_1)
# Out:
# [0.1645025429525473, 0.7737761313115084, 0.24168317373265658, 0.39387075468473776, 0.7103245223870125, 0.3233451030352281, 0.20307879595838751, 0.9670580155667161, 0.02407810544409794, 0.2997018791077599, 0.14939885417117948, 0.9374582081643075, 0.3801804972177798, 0.34880995900770895, 0.3877083867859057, 0.8125164915341834, 0.3278100146889733, 0.0887316215123819, 0.3011947173504146, 0.8048895292466585, 0.3289028326922412, 0.6041491159137797, 0.6199225674626423, 0.6985015757320556, 0.7006076174586697, 0.49756208336013064, 0.4965905869474656, 0.8892341636984498, 0.5813980530602669, 0.5216425251174484, 0.43039335415060487, 0.21290445925852453, 0.8230805562014476, 0.14878640520324815, 0.3249503633721236, 0.7840920532516245, 0.9340867358906904, 0.8931056156654091, 0.7088059358903991, 0.8874622350776287, 0.3122000415938764, 0.14504587261346957, 0.24719839307870184, 0.38811284059148266, 0.8232030034980777, 0.9782766952448745, 0.18856436581100078, 0.3844943836302368, 0.2323231247175228, 0.3712466379396586, 0.2126047148768182, 0.16211890630054726, 0.026906563068397338, 0.0665069514761909, 0.7710755461772179, 0.3022181664783299, 0.15185730754640026, 0.18801977366529732, 0.06296645577926463, 0.08102372364801491, 0.9859468114876548, 0.09760878600235046, 0.9572596469314012, 0.9319012634863224, 0.12431490953978042, 0.6100802213672991, 0.16760532008011575, 0.33751929482890786, 0.369871904790291, 0.5943165162769826, 0.9447851360073825, 0.7683026690542143, 0.2359141740833024, 0.5049340761822032, 0.08932357863058371, 0.6789152662902114, 0.33162163688421575, 0.1663608032435251, 0.16977642725925368, 0.15739283364722922, 0.30722997178550826, 0.5075501122409294, 0.6660107087993541, 0.9906004232762893, 0.5857558114034893, 0.4026707235693887, 0.8118574750924554, 0.14796524004440315, 0.1617266692946795, 0.6974538302089928, 0.6209985176554096, 0.36708823662757206, 0.44448115198261107, 0.4455832062927052, 0.24841884786502955, 0.7189368558992031, 0.6352967220130832, 0.7478863210901199, 0.47063179850762693, 0.1942625333086645]
# StatsModels.TableRegressionModel{LinearModel{GLM.LmResp{Array{Float64,1}},GLM.DensePredChol{Float64,Cholesky{Float64,Array{Float64,2}}}},Array{Float64,2}}
#
# y ~ 1 + x
#
# Coefficients:
# ──────────────────────────────────────────────────────────────────────────
#                  Coef.  Std. Error       t  Pr(>|t|)  Lower 95%  Upper 95%
# ──────────────────────────────────────────────────────────────────────────
# (Intercept)  0.0503595  0.00529003    9.52    <1e-14  0.0398616  0.0608574
# x            1.99384    0.00977402  203.99    <1e-99  1.97445    2.01324
# ──────────────────────────────────────────────────────────────────────────

# %%
s = scatter(convert(Array,data[:,1]), convert(Array,data[:,2]))
plot!(s)

# %%
data = CSV.read("admit.csv", normalizenames=true)
rename!(data, [:id, :y, :x, :label])
# Out:
# 400×4 DataFrame
# │ Row │ id    │ y     │ x       │ label │
# │     │ Int64 │ Int64 │ Float64 │ Int64 │
# ├─────┼───────┼───────┼─────────┼───────┤
# │ 1   │ 0     │ 380   │ 3.61    │ 3     │
# │ 2   │ 1     │ 660   │ 3.67    │ 3     │
# │ 3   │ 1     │ 800   │ 4.0     │ 1     │
# │ 4   │ 1     │ 640   │ 3.19    │ 4     │
# │ 5   │ 0     │ 520   │ 2.93    │ 4     │
# │ 6   │ 1     │ 760   │ 3.0     │ 2     │
# │ 7   │ 1     │ 560   │ 2.98    │ 1     │
# │ 8   │ 0     │ 400   │ 3.08    │ 2     │
# │ 9   │ 1     │ 540   │ 3.39    │ 3     │
# │ 10  │ 0     │ 700   │ 3.92    │ 2     │
# ⋮
# │ 390 │ 0     │ 640   │ 3.51    │ 2     │
# │ 391 │ 1     │ 800   │ 3.05    │ 2     │
# │ 392 │ 1     │ 660   │ 3.88    │ 2     │
# │ 393 │ 1     │ 600   │ 3.38    │ 3     │
# │ 394 │ 1     │ 620   │ 3.75    │ 2     │
# │ 395 │ 1     │ 460   │ 3.99    │ 3     │
# │ 396 │ 0     │ 620   │ 4.0     │ 2     │
# │ 397 │ 0     │ 560   │ 3.04    │ 3     │
# │ 398 │ 0     │ 460   │ 2.63    │ 2     │
# │ 399 │ 0     │ 700   │ 3.65    │ 2     │
# │ 400 │ 0     │ 600   │ 3.89    │ 3     │

# %%
println(lm(@formula(y ~ x), data))
# Out:
# StatsModels.TableRegressionModel{LinearModel{GLM.LmResp{Array{Float64,1}},GLM.DensePredChol{Float64,Cholesky{Float64,Array{Float64,2}}}},Array{Float64,2}}
#
# y ~ 1 + x
#
# Coefficients:
# ──────────────────────────────────────────────────────────────────────
#                Coef.  Std. Error     t  Pr(>|t|)  Lower 95%  Upper 95%
# ──────────────────────────────────────────────────────────────────────
# (Intercept)  192.304     47.9157  4.01    <1e-4     98.1047    286.504
# x            116.639     14.0468  8.30    <1e-14    89.0241    144.255
# ──────────────────────────────────────────────────────────────────────

# %%
s = scatter(convert(Array,data[:,3]), convert(Array,data[:,2]))
# plot!(s)
x_data = convert(Array,data[:,3])

theta_1 = 192.304
theta_2 = 116.639
plot!(s, x_data, x_data * theta_2 .+ theta_1)

# %%
data = CSV.read("admit.csv", normalizenames=true)
rename!(data, [:id, :y, :x, :label])
println(lm(@formula(y ~ x), data))

x_data = convert(Array, data[:x])
y_data = convert(Array,data[:y])
s = scatter(x_data, y_data )

theta_1 = 192.304
theta_2 = 116.639
plot!(s, x_data, x_data * theta_2 .+ theta_1)
# Out:
# StatsModels.TableRegressionModel{LinearModel{GLM.LmResp{Array{Float64,1}},GLM.DensePredChol{Float64,Cholesky{Float64,Array{Float64,2}}}},Array{Float64,2}}
#
# y ~ 1 + x
#
# Coefficients:
# ──────────────────────────────────────────────────────────────────────
#                Coef.  Std. Error     t  Pr(>|t|)  Lower 95%  Upper 95%
# ──────────────────────────────────────────────────────────────────────
# (Intercept)  192.304     47.9157  4.01    <1e-4     98.1047    286.504
# x            116.639     14.0468  8.30    <1e-14    89.0241    144.255
# ──────────────────────────────────────────────────────────────────────
