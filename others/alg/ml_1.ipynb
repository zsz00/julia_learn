# %%
using CSV, LinearAlgebra, Statistics, Compat, GLM, DataFrames
using Plots
using RDatasets
using MLJ

# %%
# data = DataFrame(y = rand(100), x = categorical(repeat([1, 2, 3, 4], 25)))
x = rand(100)
data = DataFrame(x =x, y = 2x .+ 0.1*rand(100))
# println(data.x)
println(lm(@formula(y ~ x), data))

x_data = convert(Array, data[:x])
y_data = convert(Array,data[:y])
s = scatter(x_data, y_data )

theta_1 = 0.0547491
theta_2 = 1.99782
plot!(s, x_data, x_data * theta_2 .+ theta_1)
# Out:
# ArgumentError: syntax df[column] is not supported use df[!, column] instead
#
#
#
# Stacktrace:
#
#   [1] getindex(#unused#::DataFrame, #unused#::Symbol)
#
#     @ DataFrames ~/.julia/packages/DataFrames/BM4OQ/src/abstractdataframe/abstractdataframe.jl:2257
#
#   [2] top-level scope
#
#     @ ~/codes/julia_learn/others/alg/ml_1.ipynb:7
#
#   [3] eval
#
#     @ ./boot.jl:373 [inlined]
#
#   [4] include_string(mapexpr::typeof(REPL.softscope), mod::Module, code::String, filename::String)
#
#     @ Base ./loading.jl:1196
#
#   [5] #invokelatest#2
#
#     @ ./essentials.jl:716 [inlined]
#
#   [6] invokelatest
#
#     @ ./essentials.jl:714 [inlined]
#
#   [7] (::VSCodeServer.var"#150#151"{VSCodeServer.NotebookRunCellArguments, String})()
#
#     @ VSCodeServer ~/.vscode-server/extensions/julialang.language-julia-1.5.8/scripts/packages/VSCodeServer/src/serve_notebook.jl:18
#
#   [8] withpath(f::VSCodeServer.var"#150#151"{VSCodeServer.NotebookRunCellArguments, String}, path::String)
#
# ...

# %%
# s = scatter(convert(Array,data[:,1]), convert(Array,data[:,2]))
s = scatter(data)
plot!(s)
# Out:
# Cannot convert DataFrame to series data for plotting
#
# Stacktrace:
#  [1] error(::String) at ./error.jl:33
#  [2] _prepare_series_data(::DataFrame) at /home/zhangyong/.julia/packages/RecipesPipeline/uPBKQ/src/series.jl:8
#  [3] _series_data_vector(::DataFrame, ::Dict{Symbol,Any}) at /home/zhangyong/.julia/packages/RecipesPipeline/uPBKQ/src/series.jl:27
#  [4] macro expansion at /home/zhangyong/.julia/packages/RecipesPipeline/uPBKQ/src/series.jl:145 [inlined]
#  [5] apply_recipe(::AbstractDict{Symbol,Any}, ::Type{RecipesPipeline.SliceIt}, ::Any, ::Any, ::Any) at /home/zhangyong/.julia/packages/RecipesBase/92zOw/src/RecipesBase.jl:282
#  [6] _process_userrecipes!(::Any, ::Any, ::Any) at /home/zhangyong/.julia/packages/RecipesPipeline/uPBKQ/src/user_recipe.jl:36
#  [7] recipe_pipeline!(::Any, ::Any, ::Any) at /home/zhangyong/.julia/packages/RecipesPipeline/uPBKQ/src/RecipesPipeline.jl:70
# ...

# %%
data = CSV.read("admit.csv", normalizenames=true)
rename!(data, [:id, :y, :x, :label])
# Out:
# 400×4 DataFrame
# │ Row │ id    │ y     │ x       │ label │
# │     │ Int64 │ Int64 │ Float64 │ Int64 │
# ├─────┼───────┼───────┼─────────┼───────┤
# │ 1   │ 0     │ 380   │ 3.61    │ 3     │
# │ 2   │ 1     │ 660   │ 3.67    │ 3     │
# │ 3   │ 1     │ 800   │ 4.0     │ 1     │
# │ 4   │ 1     │ 640   │ 3.19    │ 4     │
# │ 5   │ 0     │ 520   │ 2.93    │ 4     │
# │ 6   │ 1     │ 760   │ 3.0     │ 2     │
# │ 7   │ 1     │ 560   │ 2.98    │ 1     │
# │ 8   │ 0     │ 400   │ 3.08    │ 2     │
# │ 9   │ 1     │ 540   │ 3.39    │ 3     │
# │ 10  │ 0     │ 700   │ 3.92    │ 2     │
# ⋮
# │ 390 │ 0     │ 640   │ 3.51    │ 2     │
# │ 391 │ 1     │ 800   │ 3.05    │ 2     │
# │ 392 │ 1     │ 660   │ 3.88    │ 2     │
# │ 393 │ 1     │ 600   │ 3.38    │ 3     │
# │ 394 │ 1     │ 620   │ 3.75    │ 2     │
# │ 395 │ 1     │ 460   │ 3.99    │ 3     │
# │ 396 │ 0     │ 620   │ 4.0     │ 2     │
# │ 397 │ 0     │ 560   │ 3.04    │ 3     │
# │ 398 │ 0     │ 460   │ 2.63    │ 2     │
# ...

# %%
println(lm(@formula(y ~ x), data))
# Out:
# StatsModels.TableRegressionModel{LinearModel{GLM.LmResp{Array{Float64,1}},GLM.DensePredChol{Float64,Cholesky{Float64,Array{Float64,2}}}},Array{Float64,2}}
#
# y ~ 1 + x
#
# Coefficients:
# ──────────────────────────────────────────────────────────────────────
#                Coef.  Std. Error     t  Pr(>|t|)  Lower 95%  Upper 95%
# ──────────────────────────────────────────────────────────────────────
# (Intercept)  192.304     47.9157  4.01    <1e-4     98.1047    286.504
# x            116.639     14.0468  8.30    <1e-14    89.0241    144.255
# ──────────────────────────────────────────────────────────────────────

# %%
s = scatter(convert(Array,data[:,3]), convert(Array,data[:,2]))
# plot!(s)
x_data = convert(Array,data[:,3])

theta_1 = 192.304
theta_2 = 116.639
plot!(s, x_data, x_data * theta_2 .+ theta_1)

# %%
data = CSV.read("admit.csv", normalizenames=true)
rename!(data, [:id, :y, :x, :label])
println(lm(@formula(y ~ x), data))

x_data = convert(Array, data[:x])
y_data = convert(Array,data[:y])
s = scatter(x_data, y_data )

theta_1 = 192.304
theta_2 = 116.639
plot!(s, x_data, x_data * theta_2 .+ theta_1)
# Out:
# StatsModels.TableRegressionModel{LinearModel{GLM.LmResp{Array{Float64,1}},GLM.DensePredChol{Float64,Cholesky{Float64,Array{Float64,2}}}},Array{Float64,2}}
#
# y ~ 1 + x
#
# Coefficients:
# ──────────────────────────────────────────────────────────────────────
#                Coef.  Std. Error     t  Pr(>|t|)  Lower 95%  Upper 95%
# ──────────────────────────────────────────────────────────────────────
# (Intercept)  192.304     47.9157  4.01    <1e-4     98.1047    286.504
# x            116.639     14.0468  8.30    <1e-14    89.0241    144.255
# ──────────────────────────────────────────────────────────────────────
